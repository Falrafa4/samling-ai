# %% [markdown]
# # **Libraries**

# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine

import folium
import json

from ortools.constraint_solver import pywrapcp
from ortools.constraint_solver import routing_enums_pb2

from math import radians, sin, cos, sqrt, atan2

# %% [markdown]
# # **Data Collection**

# %%
DATABASE_URL = "sqlite:///C:/Users/Xavier/Documents/Git Clone/samling-ai/backend/samling.db"
engine = create_engine(DATABASE_URL)

# %%
latest_batch = pd.read_sql("""
SELECT MAX(forecast_batch_id) AS batch
FROM volume_predictions
""", engine).iloc[0]["batch"]

latest_batch
# Out:
# 'batch_20260713_225957'

# %%
forecast_df = pd.read_sql(f"""
SELECT *
FROM volume_predictions
WHERE forecast_batch_id = '{latest_batch}'
""", engine)

forecast_df.head()
# Out:
#     id           created_at  predicted_volume_percentage  \
# 0  151  2026-07-13 15:59:57                    90.961467
# 1  152  2026-07-13 15:59:57                    85.612723
# 2  153  2026-07-13 15:59:57                    83.692628
# 3  154  2026-07-13 15:59:57                    81.647069
# 4  155  2026-07-13 15:59:57                    81.558708
#
#        forecast_batch_id         kecamatan  tps_id  priority_rank  \
# 0  batch_20260713_225957          Cipayung      21              1
# 1  batch_20260713_225957  Mampang Prapatan      85              2
# 2  batch_20260713_225957            Cakung       2              3
# 3  batch_20260713_225957    Kebayoran Baru      57              4
# 4  batch_20260713_225957       Tanah Abang     143              5
#
#   prediction_status model_version
# 0          CRITICAL          v1.0
# 1           WARNING          v1.0
# 2           WARNING          v1.0
# 3           WARNING          v1.0
# 4           WARNING          v1.0

# %%
zones = pd.read_sql("""
SELECT
    id,
    kecamatan,
    latitude,
    longitude
FROM zones
""", engine)

forecast_df = forecast_df.merge(
    zones,
    left_on="tps_id",
    right_on="id"
)

forecast_df.head()
# Out:
#    id_x           created_at  predicted_volume_percentage  \
# 0   151  2026-07-13 15:59:57                    90.961467
# 1   152  2026-07-13 15:59:57                    85.612723
# 2   153  2026-07-13 15:59:57                    83.692628
# 3   154  2026-07-13 15:59:57                    81.647069
# 4   155  2026-07-13 15:59:57                    81.558708
#
#        forecast_batch_id       kecamatan_x  tps_id  priority_rank  \
# 0  batch_20260713_225957          Cipayung      21              1
# 1  batch_20260713_225957  Mampang Prapatan      85              2
# 2  batch_20260713_225957            Cakung       2              3
# 3  batch_20260713_225957    Kebayoran Baru      57              4
# 4  batch_20260713_225957       Tanah Abang     143              5
#
#   prediction_status model_version  id_y       kecamatan_y  latitude  \
# 0          CRITICAL          v1.0    21          Cipayung -6.270319
# 1           WARNING          v1.0    85  Mampang Prapatan -6.297520
# 2           WARNING          v1.0     2            Cakung -6.283724
# 3           WARNING          v1.0    57    Kebayoran Baru -6.262663
# 4           WARNING          v1.0   143       Tanah Abang -6.174176
#
#     longitude
# 0  106.913076
# 1  106.776265
# 2  106.909670
# 3  106.781850
# 4  106.839083

# %%
forecast_df = forecast_df[
    forecast_df["prediction_status"] != "NORMAL"
].copy()

forecast_df = forecast_df.sort_values("priority_rank")

forecast_df.reset_index(drop=True, inplace=True)

forecast_df.head()
# Out:
#    id_x           created_at  predicted_volume_percentage  \
# 0   151  2026-07-13 15:59:57                    90.961467
# 1   152  2026-07-13 15:59:57                    85.612723
# 2   153  2026-07-13 15:59:57                    83.692628
# 3   154  2026-07-13 15:59:57                    81.647069
# 4   155  2026-07-13 15:59:57                    81.558708
#
#        forecast_batch_id       kecamatan_x  tps_id  priority_rank  \
# 0  batch_20260713_225957          Cipayung      21              1
# 1  batch_20260713_225957  Mampang Prapatan      85              2
# 2  batch_20260713_225957            Cakung       2              3
# 3  batch_20260713_225957    Kebayoran Baru      57              4
# 4  batch_20260713_225957       Tanah Abang     143              5
#
#   prediction_status model_version  id_y       kecamatan_y  latitude  \
# 0          CRITICAL          v1.0    21          Cipayung -6.270319
# 1           WARNING          v1.0    85  Mampang Prapatan -6.297520
# 2           WARNING          v1.0     2            Cakung -6.283724
# 3           WARNING          v1.0    57    Kebayoran Baru -6.262663
# 4           WARNING          v1.0   143       Tanah Abang -6.174176
#
#     longitude
# 0  106.913076
# 1  106.776265
# 2  106.909670
# 3  106.781850
# 4  106.839083

# %%
drivers = pd.read_sql("""
SELECT
    users.id,
    users.name,
    users.username,
    users.whatsapp_number,
    users.status,
    users.role,
    users.coverage_area,

    fleets.id AS fleet_id,
    fleets.name AS fleet_name,
    fleets.category,
    fleets.type,
    fleets.capacity,
    fleets.total_units

FROM users
LEFT JOIN fleets
    ON users.fleet_id = fleets.id

WHERE users.role = 'driver'
""", engine)

drivers["truck_capacity_kg"] = (
    drivers["capacity"]
    .str.extract(r"(\d+)")
    .astype(int)
    * 1000
)

drivers.head()
# Out:
#    id           name       username whatsapp_number   status    role  \
# 0   2     Budi Utomo    driver_budi   6281234567890  Offline  driver
# 1   3    Joko Susilo    driver_joko   6281298765432  Offline  driver
# 2   4   Agus Saputra    driver_agus   6281311223344  Offline  driver
# 3   5  Herman Wijaya  driver_herman   6281355667788  Offline  driver
# 4   6  Rudy Hermawan    driver_rudy   6281288990011  Offline  driver
#
#      coverage_area  fleet_id          fleet_name category          type  \
# 0    Jakarta Pusat         6    Dump Truck Besar   Tengah    Dump Truck
# 1    Jakarta Barat         5      Arm Roll Besar   Tengah      Arm Roll
# 2  Jakarta Selatan         7  Truk Compactor RDF   Tengah     Compactor
# 3    Jakarta Timur         4      Arm Roll Kecil   Tengah      Arm Roll
# 4    Jakarta Utara         8        Truk Tronton   Tengah  Truk Tronton
#
#   capacity  total_units  truck_capacity_kg
# 0    8 Ton          557               8000
# 1    5 Ton          143               5000
# 2    5 Ton          148               5000
# 3    3 Ton          200               3000
# 4   10 Ton           25              10000

# %%
with open('../../../core/depots.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

print(data)
# Out:
# {'Jakarta Pusat': {'latitude': -6.1844, 'longitude': 106.8302, 'name': 'Depot DLH Jakarta Pusat'}, 'Jakarta Utara': {'latitude': -6.1244, 'longitude': 106.8912, 'name': 'Depot DLH Jakarta Utara'}, 'Jakarta Barat': {'latitude': -6.1674, 'longitude': 106.7637, 'name': 'Depot DLH Jakarta Barat'}, 'Jakarta Selatan': {'latitude': -6.2701, 'longitude': 106.8077, 'name': 'Depot DLH Jakarta Selatan'}, 'Jakarta Timur': {'latitude': -6.225, 'longitude': 106.9004, 'name': 'Depot DLH Jakarta Timur'}, 'Kepulauan Seribu': {'latitude': -5.6124, 'longitude': 106.5612, 'name': 'Depot DLH Kepulauan Seribu'}}

# %%
AREA_MAPPING = {
    "Cakung": "Jakarta Timur",
    "Ciracas": "Jakarta Timur",
    "Cipayung": "Jakarta Timur",
    "Duren Sawit": "Jakarta Timur",
    "Jatinegara": "Jakarta Timur",
    "Kramat Jati": "Jakarta Timur",
    "Makasar": "Jakarta Timur",
    "Matraman": "Jakarta Timur",
    "Pasar Rebo": "Jakarta Timur",
    "Pulogadung": "Jakarta Timur",

    "Cengkareng": "Jakarta Barat",
    "Grogol Petamburan": "Jakarta Barat",
    "Kalideres": "Jakarta Barat",
    "Kebon Jeruk": "Jakarta Barat",
    "Kembangan": "Jakarta Barat",
    "Palmerah": "Jakarta Barat",
    "Tambora": "Jakarta Barat",
    "Taman Sari": "Jakarta Barat",

    "Cilandak": "Jakarta Selatan",
    "Jagakarsa": "Jakarta Selatan",
    "Kebayoran Baru": "Jakarta Selatan",
    "Kebayoran Lama": "Jakarta Selatan",
    "Mampang Prapatan": "Jakarta Selatan",
    "Pancoran": "Jakarta Selatan",
    "Pasar Minggu": "Jakarta Selatan",
    "Pesanggrahan": "Jakarta Selatan",
    "Setiabudi": "Jakarta Selatan",
    "Tebet": "Jakarta Selatan",

    "Cempaka Putih": "Jakarta Pusat",
    "Gambir": "Jakarta Pusat",
    "Johar Baru": "Jakarta Pusat",
    "Kemayoran": "Jakarta Pusat",
    "Menteng": "Jakarta Pusat",
    "Sawah Besar": "Jakarta Pusat",
    "Senen": "Jakarta Pusat",
    "Tanah Abang": "Jakarta Pusat",

    "Cilincing": "Jakarta Utara",
    "Kelapa Gading": "Jakarta Utara",
    "Koja": "Jakarta Utara",
    "Pademangan": "Jakarta Utara",
    "Penjaringan": "Jakarta Utara",
    "Tanjung Priok": "Jakarta Utara",

    "Kepulauan Seribu Selatan": "Kepulauan Seribu",
    "Kepulauan Seribu Utara": "Kepulauan Seribu",
}

# %%
forecast_df["area"] = forecast_df["kecamatan_x"].map(AREA_MAPPING)
forecast_df
# Out:
#     id_x           created_at  predicted_volume_percentage  \
# 0    151  2026-07-13 15:59:57                    90.961467
# 1    152  2026-07-13 15:59:57                    85.612723
# 2    153  2026-07-13 15:59:57                    83.692628
# 3    154  2026-07-13 15:59:57                    81.647069
# 4    155  2026-07-13 15:59:57                    81.558708
# 5    156  2026-07-13 15:59:57                    79.077662
# 6    157  2026-07-13 15:59:57                    78.550416
# 7    158  2026-07-13 15:59:57                    78.492578
# 8    159  2026-07-13 15:59:57                    77.964339
# 9            WARNING          v1.0    12                  Cilandak -6.236315
# 10           WARNING          v1.0    76                      Koja -6.109578
# 11           WARNING          v1.0    71                 Kembangan -6.165042
# 12           WARNING          v1.0    11                Cengkareng -6.127359
# 13           WARNING          v1.0    70                 Kembangan -6.162347
# 14           WARNING          v1.0   114              Pesanggrahan -6.289669
# 15           WARNING          v1.0   111               Penjaringan -6.115366
# 16           WARNING          v1.0    80               Kramat Jati -6.219356
# 17           WARNING          v1.0    96                Pademangan -6.106477
# 18           WARNING          v1.0    45                Jatinegara -6.227897
# 19           WARNING          v1.0     7             Cempaka Putih -6.155030
# 20           WARNING          v1.0    53                 Kalideres -6.150866
# 21           WARNING          v1.0   124    Kepulauan Seribu Utara -5.898236
# 22           WARNING          v1.0   145             Tanjung Priok -6.153462
# 23           WARNING          v1.0   104              Pasar Minggu -6.294049
# 24           WARNING          v1.0   118              Pesanggrahan -6.250903
# 25           WARNING          v1.0    95                Pademangan -6.125356
# 26           WARNING          v1.0   139                   Tambora -6.153232
#
#      longitude              area
# 0   106.913076     Jakarta Timur
# 1   106.776265   Jakarta Selatan
# 2   106.909670     Jakarta Timur
# 3   106.781850   Jakarta Selatan
# 4   106.839083     Jakarta Pusat
# 5   106.781816   Jakarta Selatan
# 6   106.916872     Jakarta Utara
# 7   106.915067     Jakarta Utara
# 8   106.565349  Kepulauan Seribu
# 9   106.784265   Jakarta Selatan
# 10  106.918955     Jakarta Utara
# 11  106.719131     Jakarta Barat
# 12  106.757053     Jakarta Barat
# 13  106.743745     Jakarta Barat
# 14  106.778409   Jakarta Selatan
# 15  106.916711     Jakarta Utara
# 16  106.918830     Jakarta Timur
# 17  106.898546     Jakarta Utara
# 18  106.915670     Jakarta Timur
# 19  106.800649     Jakarta Pusat
# 20  106.729061     Jakarta Barat
# 21  106.560033  Kepulauan Seribu
# 22  106.887898     Jakarta Utara
# 23  106.829185   Jakarta Selatan
# 24  106.784540   Jakarta Selatan
# 25  106.927244     Jakarta Utara
# 26  106.769166     Jakarta Barat

# %%
forecast_df = forecast_df.merge(
    drivers,
    left_on="area",
    right_on="area",
    how="left"
)

forecast_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2908\3854125269.py in ?()
# ----> 1 forecast_df = forecast_df.merge(
#       2     drivers,
#       3     left_on="area",
#       4     right_on="area",
#
# c:\Users\Xavier\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10855         validate: MergeValidate | None = None,
#   10856     ) -> DataFrame:
#   10857         from pandas.core.reshape.merge import merge
#   10858
# > 10859         return merge(
#   10860             self,
#   10861             right,
#   10862             how=how,
#
# c:\Users\Xavier\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\Xavier\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\Xavier\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1294                         # Then we're either Hashable or a wrong-length arraylike,
#    1295                         #  the latter of which will raise
#    1296                         rk = cast(Hashable, rk)
#    1297                         if rk is not None:
# -> 1298                             right_keys.append(right._get_label_or_level_values(rk))
#    1299                         else:
#    1300                             # work-around for merge_asof(right_index=True)
#    1301                             right_keys.append(right.index._values)
#
# c:\Users\Xavier\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'area'
